# %%
import threading
import time
import datetime

def print_time(name, delay, times):
    print("Starting", name)
    for _ in range(times):
        time.sleep(delay)
        print(name + ":", datetime.datetime.now())
    print("Exiting", name)

print("Starting Main Thread")

t1 = threading.Thread(target=print_time, args=("Google", 1, 3))
t2 = threading.Thread(target=print_time, args=("Yahoo", 2, 3))
t3 = threading.Thread(target=print_time, args=("Facebook", 3, 3))

t1.start()
t2.start()
t3.start()

t1.join()
t2.join()
t3.join()

print("Exiting Main Thread")
# Out:
# Starting Main Thread
# Starting Google
# Starting Yahoo
# Starting Facebook
# Google: 2026-01-03 20:32:15.180530
# Yahoo: 2026-01-03 20:32:16.181107
# Google: 2026-01-03 20:32:16.191495
# Facebook: 2026-01-03 20:32:17.181714
# Google: 2026-01-03 20:32:17.193053
# Exiting Google
# Yahoo: 2026-01-03 20:32:18.183966
# Facebook:Yahoo: 2026-01-03 20:32:20.184903
# Exiting Yahoo
#  2026-01-03 20:32:20.184903
# Facebook: 2026-01-03 20:32:23.186554
# Exiting Facebook
# Exiting Main Thread
