# %%
import pandas as pd
ser=pd.Series([1,3,6,10,15,21,27,35])
print(ser)
# Out:
# 0     1
# 1     3
# 2     6
# 3    10
# 4    15
# 5    21
# 6    27
# 7    35
# dtype: int64

# %%
hieu=ser.diff().diff()
print('hiệu số của hiệu số các số trong ser:\n',hieu.fillna(0))
# Out:
# hiệu số của hiệu số các số trong ser:
#  0    0.0
# 1    0.0
# 2    1.0
# 3    1.0
# 4    1.0
# 5    1.0
# 6    0.0
# 7    2.0
# dtype: float64
