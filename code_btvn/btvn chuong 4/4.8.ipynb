# %%
import pandas as pd
import numpy as np

ser=pd.Series(np.random.random(20))
ser
# Out:
# 0     0.178425
# 1     0.189113
# 2     0.283138
# 3     0.277442
# 4     0.045040
# 5     0.767805
# 6     0.171641
# 7     0.929247
# 8     0.150850
# 9     0.590706
# 10    0.231773
# 11    0.188608
# 12    0.656864
# 13    0.030328
# 14    0.952705
# 15    0.226328
# 16    0.597262
# 17    0.386391
# 18    0.569980
# 19    0.274806
# dtype: float64
