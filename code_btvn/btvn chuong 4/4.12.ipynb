# %%
import pandas as pd

ser1=pd.Series(range(5))
ser2=pd.Series(list('abcde'))
print(ser1)
print(ser2)
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %%
n=ser2[ser1]
print(n)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object
