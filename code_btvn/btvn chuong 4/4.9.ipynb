# %%
import pandas as pd
import numpy as np

ser=pd.Series(np.random.randint(1,10,35))
ser
# Out:
# 0     4
# 1     7
# 2     5
# 3     1
# 4     2
# 5     1
# 6     5
# 7     6
# 8     1
# 9     5
# 10    2
# 11    1
# 12    7
# 13    5
# 14    6
# 15    9
# 16    1
# 17    6
# 18    9
# 19    4
# 20    6
# 21    3
# 22    7
# 23    9
# 24    9
# 25    5
# 26    3
# 27    8
# 28    5
# 29    9
# 30    7
# 31    4
# 32    2
# 33    5
# 34    5
# dtype: int32

# %%
ser_df=pd.DataFrame(ser,([7,5]))
print(ser)
# Out:
# 0     4
# 1     7
# 2     5
# 3     1
# 4     2
# 5     1
# 6     5
# 7     6
# 8     1
# 9     5
# 10    2
# 11    1
# 12    7
# 13    5
# 14    6
# 15    9
# 16    1
# 17    6
# 18    9
# 19    4
# 20    6
# 21    3
# 22    7
# 23    9
# 24    9
# 25    5
# 26    3
# 27    8
# 28    5
# 29    9
# 30    7
# 31    4
# 32    2
# 33    5
# 34    5
# dtype: int32
