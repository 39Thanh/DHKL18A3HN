# %%
import pandas as pd
import numpy as np
ser=pd.Series(np.random.randint(1,10,7))
print(ser)
# Out:
# 0    3
# 1    7
# 2    3
# 3    9
# 4    8
# 5    4
# 6    3
# dtype: int32

# %%
vi_tri=ser[ser%3==0].index.to_list()
print('vị trí của các bội số của 3 từ ser:\n',vi_tri)
# Out:
# vị trí của các bội số của 3 từ ser:
#  [0, 2, 3, 6]
