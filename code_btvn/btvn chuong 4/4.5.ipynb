# %%
import pandas as pd
import numpy as np
ser=pd.Series(np.random.normal(10,5,25))
ser
# Out:
# 0      5.464730
# 1     10.946245
# 2      5.038244
# 3     19.287378
# 4     13.499937
# 5     15.513220
# 6     12.735432
# 7      4.887362
# 8      5.304012
# 9     12.183375
# 10    13.053712
# 11     5.793722
# 12    13.414420
# 13     3.610077
# 14     3.701105
# 15    16.632123
# 16    16.114365
# 17     8.266121
# 18    13.394447
# 19     9.021810
# 20     9.352013
# 21    11.050750
# 22     3.545378
# 23     6.858484
# 24    14.411640
# dtype: float64

# %%
#1: Giá trị tối thiểu của ser
print('gia tri toi thieu: ',ser.min())
# Out:
# gia tri toi thieu:  3.5453778051755522

# %%
#2
print('phan centile thu 25: ',ser.describe()['25%'])
# Out:
# phan centile thu 25 5.464730088865262

# %%
#3
print('trung vi: ',ser.describe()['50%'])
# Out:
# trung vi:  10.946244937665188

# %%
#4
print('phan centile thu 75: ',ser.describe()['75%'])
# Out:
# phan centile thu 75:  13.414420384589224

# %%
#5
print('gia tri toi da: ',ser.max())
# Out:
# gia tri toi da:  19.287378433498052
