# %%
import sqlite3

conn = sqlite3.connect("ql_nhan_vien.db")
cur = conn.cursor()

# Bảng PHONG
cur.execute("""
CREATE TABLE IF NOT EXISTS PHONG (
    id INTEGER PRIMARY KEY,
    ten_phong TEXT NOT NULL
)
""")

# Bảng NHAN_VIEN
cur.execute("""
CREATE TABLE IF NOT EXISTS NHAN_VIEN (
    id INTEGER PRIMARY KEY,
    ho_ten TEXT NOT NULL,
    tuoi INTEGER NOT NULL,
    dia_chi TEXT NOT NULL,
    luong REAL NOT NULL,
    id_phong INTEGER,
    FOREIGN KEY(id_phong) REFERENCES PHONG(id)
)
""")

conn.commit()

# %% [markdown]
# them phong ban

# %%
cur.execute("INSERT INTO PHONG VALUES (?, ?)", (1, "IT"))
conn.commit()

# %% [markdown]
# them nhan vien

# %%
cur.execute("""
INSERT INTO NHAN_VIEN VALUES (?, ?, ?, ?, ?, ?)
""", (1, "Nguyen Van A", 22, "Ha Noi", 8000000, 1))

conn.commit()

# %% [markdown]
# xem danh sach nhan vien

# %%
cur.execute("SELECT * FROM NHAN_VIEN")
for row in cur.fetchall():
    print(row)

conn.close()
# Out:
# (1, 'Nguyen Van A', 22, 'Ha Noi', 8000000.0, 1)
