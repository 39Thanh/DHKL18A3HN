# %%
import sqlite3

conn=sqlite3.connect('test.db')
cur=conn.cursor()

cur.execute("""
CREATE TABLE IF NOT EXISTS sinhvien (
    id INTEGER PRIMARY KEY,
    ho ten TEXT,
    tuoi INTEGER
)
""")

conn.commit()
conn.close()
