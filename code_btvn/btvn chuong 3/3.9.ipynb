# %%
import numpy as np

euro12=np.genfromtxt('euro2012.csv',encoding='UTF-8', delimiter=',',dtype=None,names=True)
print(euro12)

# %%
print(type(euro12))
print(euro12.shape)
print(euro12.dtype.names)
# Out:
# <class 'numpy.ndarray'>
# (14,)
# ('Goals', 'Teams', 'Yellow_Cards', 'Red_Cards')

# %%
#1
print(euro12['Goals'])
# Out:
# [ 1  2  3  4 56  8  0  4  6  8  3  3 56  5]

# %%
#2
print(len(euro12['Teams']))
# Out:
# 14

# %%
#3
euro12.dtype
# Out:
# dtype([('Goals', '<i8'), ('Teams', '<U4'), ('Yellow_Cards', '<i8'), ('Red_Cards', '<i8')])

# %%
#4
discipline=euro12[['Teams','Yellow_Cards','Red_Cards']]
discipline
# Out:
# array([('dg',  2,  0), ('gd', 34, 76), ('hd',  4,  4), ('hd', 76, 53),
#        ('sr',  5,  2), ('yr',  9,  2), ('lk',  3,  4), ('yt0', 34,  6),
#        ('try', 12,  7), ('ewr', 43,  1), ('er',  5,  0), ('weq2',  4,  1),
#        ('trfg', 21,  2), ('yer',  4,  6)],
#       dtype={'names': ['Teams', 'Yellow_Cards', 'Red_Cards'], 'formats': ['<U4', '<i8', '<i8'], 'offsets': [8, 24, 32], 'itemsize': 40})

# %%
#5
sort=np.lexsort((-discipline['Yellow_Cards'],-discipline['Red_Cards']))
discipline_sort=discipline[sort]
discipline
# Out:
# array([('dg',  2,  0), ('gd', 34, 76), ('hd',  4,  4), ('hd', 76, 53),
#        ('sr',  5,  2), ('yr',  9,  2), ('lk',  3,  4), ('yt0', 34,  6),
#        ('try', 12,  7), ('ewr', 43,  1), ('er',  5,  0), ('weq2',  4,  1),
#        ('trfg', 21,  2), ('yer',  4,  6)],
#       dtype={'names': ['Teams', 'Yellow_Cards', 'Red_Cards'], 'formats': ['<U4', '<i8', '<i8'], 'offsets': [8, 24, 32], 'itemsize': 40})

# %%
#6
#tính trung bình yellow card
yellow=np.mean(euro12['Yellow_Cards'])
print('trung bình yellow cards: ',yellow)

#lọc các đội ghi hơn 6 bàn thắng
print('các đội ghi hơn 6 bàn là:\n',euro12[euro12['Goals']>6])
# Out:
# trung bình yellow cards:  18.285714285714285
# các đội ghi hơn 6 bàn là:
#  [(56, 'sr',  5, 2) ( 8, 'yr',  9, 2) ( 8, 'ewr', 43, 1)
#  (56, 'trfg', 21, 2)]

# %%
#7
g=euro12[np.char.startswith(euro12['Teams'],'G')]
print('ten cac doi bat dau voi chu G:\n',g)
# Out:
# []

# %%
#8
print(euro12[list(euro12.dtype.names[:7])])
# Out:
# [( 1, 'dg',  2,  0) ( 2, 'gd', 34, 76) ( 3, 'hd',  4,  4)
#  ( 4, 'hd', 76, 53) (56, 'sr',  5,  2) ( 8, 'yr',  9,  2)
#  ( 0, 'lk',  3,  4) ( 4, 'yt0', 34,  6) ( 6, 'try', 12,  7)
#  ( 8, 'ewr', 43,  1) ( 3, 'er',  5,  0) ( 3, 'weq2',  4,  1)
#  (56, 'trfg', 21,  2) ( 5, 'yer',  4,  6)]

# %%
#9 
print(euro12[list(euro12.dtype.names[:-3])])
# Out:
# [( 1,) ( 2,) ( 3,) ( 4,) (56,) ( 8,) ( 0,) ( 4,) ( 6,) ( 8,) ( 3,) ( 3,)
#  (56,) ( 5,)]

# %%
#10
euro12[['Teams','Goals','Yellow_Cards','Red_Cards','Shooting_Accuracy']]

# %%
#11
mask=np.isin(euro12['Teams'],['England'],['Italy'],['Russia'])
euro12[mask][['Teams','Shooting_Accuracy']]
