# %%
import numpy as np
heights=np.genfromtxt('heights.txt',encoding='utf-8',delimiter=',')
positions=np.genfromtxt('positions.txt',encoding='utf-8',delimiter=',')
print(heights)
print(positions)

# %%
#1a
np_positions=np.array(positions)
print(np_positions.dtype)

# %%
#1b
np_heights=np.array(heights)
print(np_heights.dtype)

# %%
#2
print(np_positions.mean(0))

# %%
#3
print(np_positions())

# %%
#4
