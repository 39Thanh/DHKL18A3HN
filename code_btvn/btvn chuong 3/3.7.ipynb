# %%
import numpy as np
baseball=np.genfromtxt('baseball_2D.txt',delimiter=',',encoding='utf-8',dtype=int, skip_header=1)
print(baseball)
# Out:
# [[ 67 110]
#  [ 62 164]
#  [ 71 158]
#  [ 69 166]
#  [ 67 202]
#  [ 56 239]
#  [ 64 106]
#  [ 72 221]
#  [ 63 114]
#  [ 65 170]
#  [ 67 224]
#  [ 57 160]
#  [ 57 161]
#  [ 55 145]
#  [ 55 233]
#  [ 57 155]
#  [ 71 183]
#  [ 57 134]
#  [ 56 239]
#  [ 61 198]
#  [ 71 189]
#  [ 67 175]
#  [ 55 172]
#  [ 61 171]
#  [ 75 179]
#  [ 74 228]
#  [ 72 191]
#  [ 58 202]
#  [ 67 201]
#  [ 70 143]
#  [ 65 115]
#  [ 65 122]
#  [ 75 192]
#  [ 57 154]
#  [ 61 180]
#  [ 75 114]
#  [ 57 142]
#  [ 68 132]
#  [ 69 187]
#  [ 61 134]
#  [ 61 208]
#  [ 60 199]
#  [ 67 212]
#  [ 55 244]
#  [ 75 130]
#  [ 57 240]
#  [ 71 122]
#  [ 75 213]
#  [ 63 152]
#  [ 73 188]
#  [ 64 227]
#  [ 69 219]
#  [ 73 146]
#  [ 59 232]
#  [ 74 155]
#  [ 55 190]
#  [ 58 147]
#  [ 70 222]
#  [ 75 156]
#  [ 66 148]]

# %%
#1
np_baseball=np.array(baseball)
print(np_baseball)
print("kich thuoc: ",np_baseball.shape)
print("kieu du lieu: ",np_baseball.dtype)
# Out:
# [[ 67 110]
#  [ 62 164]
#  [ 71 158]
#  [ 69 166]
#  [ 67 202]
#  [ 56 239]
#  [ 64 106]
#  [ 72 221]
#  [ 63 114]
#  [ 65 170]
#  [ 67 224]
#  [ 57 160]
#  [ 57 161]
#  [ 55 145]
#  [ 55 233]
#  [ 57 155]
#  [ 71 183]
#  [ 57 134]
#  [ 56 239]
#  [ 61 198]
#  [ 71 189]
#  [ 67 175]
#  [ 55 172]
#  [ 61 171]
#  [ 75 179]
#  [ 74 228]
#  [ 72 191]
#  [ 58 202]
#  [ 67 201]
#  [ 70 143]
#  [ 65 115]
#  [ 65 122]
#  [ 75 192]
#  [ 57 154]
#  [ 61 180]
#  [ 75 114]
#  [ 57 142]
#  [ 68 132]
#  [ 69 187]
#  [ 61 134]
#  [ 61 208]
#  [ 60 199]
#  [ 67 212]
#  [ 55 244]
#  [ 75 130]
#  [ 57 240]
#  [ 71 122]
#  [ 75 213]
#  [ 63 152]
#  [ 73 188]
#  [ 64 227]
#  [ 69 219]
#  [ 73 146]
#  [ 59 232]
#  [ 74 155]
#  [ 55 190]
#  [ 58 147]
#  [ 70 222]
#  [ 75 156]
#  [ 66 148]]
# kich thuoc:  (60, 2)
# kieu du lieu:  int64

# %%
#2
print("dong thu 50: ",np_baseball[49])
# Out:
# dong thu 50:  ['63' '152']

# %%
#3
np_weight= np_baseball[:,1]
print(np_weight)
# Out:
# [110 164 158 166 202 239 106 221 114 170 224 160 161 145 233 155 183 134
#  239 198 189 175 172 171 179 228 191 202 201 143 115 122 192 154 180 114
#  142 132 187 134 208 199 212 244 130 240 122 213 152 188 227 219 146 232
#  155 190 147 222 156 148]

# %%
#4
height_124=np_baseball[123,0]
print("chieu cao cua van dong vien thu 44: ",height_124)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[46], line 2
#       1 #4
# ----> 2 height_124=np_baseball[123,0]
#       3 print("chieu cao cua van dong vien thu 44: ",height_124)
#
# IndexError: index 123 is out of bounds for axis 0 with size 61

# %%
#5
np_heights=np_baseball[:,0]
tb_chieu_cao=np_heights.mean(axis=0)
tb_can_nang=np_weight.mean(axis=0)

print('trung binh can nang cac cau thu: ',tb_can_nang)
print('trung binh chieu cao cac cau thu: ',tb_chieu_cao)
# Out:
# trung binh can nang cac cau thu:  175.91666666666666
# trung binh chieu cao cac cau thu:  64.86666666666666

# %%
#6
