# %%
import ipykernel
ipykernel.__version__
# Out:
# '7.1.0'

# %%
pip install -U ipykernel
# Out:
# Requirement already satisfied: ipykernel in c:\users\thinkpad\appdata\local\programs\python\python313\lib\site-packages (7.1.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from ipykernel) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from ipykernel) (9.5.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from ipykernel) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from ipykernel) (25.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from ipykernel) (7.1.0)
# Requirement already satisfied: pyzmq>=25 in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from ipykernel) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: colorama in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from jupyter-client>=8.0.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.4.0)
# Requirement already satisfied: pywin32>=300 in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (311)
# Requirement already satisfied: six>=1.5 in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\thinkpad\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# vidu 7.1.1 chương trình giao diện GUI đầu tiên

# %%
import tkinter as tk 
 
# Tạo một cửa sổ chính của ứng dụng 
window = tk.Tk() 
 
# Thêm các thành phần widget  vào cửa sổ 
label = tk.Label(window, text="Hello World!") 
label.pack() 
 
#Thêm tiêu đề cho cửa  sổ 
window.title("Wellcome to Uneti!") 
#Đặt kích thước cửa sổ theo pixels 
window.geometry('280x60') 
 
# Bắt đầu vòng lặp chạy ứng dụng (lặp vô tận để hiển thị cửa sổ trên màn hình máy tính) 
window.mainloop()

# %% [markdown]
# vidu 7.1.2.1: Tạo một cửa sổ gồm một nhãn (label) có nội dung là "Hello" và font chữ "Arial Bold" cỡ chữ 50, trong giao diện người dùng

# %%
from tkinter import *
window = Tk() 
window.title("Welcome to Uneti.") 
#Thêm label có nội dung Hello, font chữ “Arial Bold, cỡ chữ 50” 
lbl = Label(window, text="Hello", font=("Arial Bold", 50)) 
#Đặt kích thước cửa sổ theo pixels 
window.geometry('280x80') 
#Xác định vị trí của label 
lbl.grid(column=0, row=0) 
# Bắt đầu vòng lặp chạy ứng dụng (lặp vô tận để hiển thị cửa sổ trên màn hình máy tính) 
window.mainloop()

# %% [markdown]
# Ví dụ 7.1.2.2. Tạo một cửa sổ gồm một nhãn (label) và một nút nhấn (button). Khi nút nhấn được nhấn, nhãn (label) sẽ được cập nhật với nội dung mới.

# %%
from tkinter import * 
window = Tk() 
window.title("Welcome to Uneti") 
window.geometry('300x80') 
lbl = Label(window, text="Hello") 
lbl.grid(column=0, row=0) 

#Hàm khi nút được nhấn 
def clicked(): 
    lbl.configure(text="Button was clicked !!") 
#Thêm một nút nhấn Click Me 
btn = Button(window, text="Click Me", bg="orange",  
fg="red",command=clicked) 
#Thiết lập vị trí của nút nhấn có màu nền và màu chữ 
btn.grid(column=5, row=0) 
window.mainloop()

# %% [markdown]
# Ví dụ7.1.2.3: Tạo Textbox trong tkinter:

# %%
import tkinter as tk
class UnetiApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Welcome to Uneti app") 
        self.root.geometry('350x80') 
 
        self.lbl1 = tk.Label(root, text="Giảng viên:") 
        self.lbl1.grid(column=0, row=0) 
 
        self.txt1 = tk.Entry(root, width=15) 
        self.txt1.grid(column=1, row=0) 
        self.txt1.focus() 
         
        self.lbl2 = tk.Label(root, text="Bộ môn:") 
        self.lbl2.grid(column=0, row=2) 
 
        self.txt2 = tk.Entry(root, width=15) 
        self.txt2.grid(column=1, row=2) 
        self.txt2.focus() 
         
        self.lbl3 = tk.Label(root, text="HP giảng dạy:") 
        self.lbl3.grid(column=0, row=3) 
 
        self.txt3 = tk.Entry(root, width=15) 
        self.txt3.grid(column=1, row=3) 
        self.txt3.focus() 
 
if __name__ == "__main__": 
    root = tk.Tk() 
    app = UnetiApp(root) 
    root.mainloop()

# %% [markdown]
# ví dụ7.1.2.4: Sử dụng lập trình hướng đối tượng để tạo Textbox và combobox

# %%
import tkinter as tk 
from tkinter import ttk 
 
class ComboboxApp: 
    def __init__(self, root): 
        self.root = root 
        self.root.title("Wellcome to Uneti App") 
        self.root.geometry('350x80') 
 
        self.options=["DHDS16A1", "DHDS 16A2", "DHDS17A1", "DHDS 17A2", "DHDS 17A3"] 
 
        self.teacher_label = tk.Label(root, text="Giảng viên:") 
        self.teacher_label.grid(row=0, column=0, padx=5, pady=5) 
 
        self.teacher_textbox = tk.Text(root, height=1, width=20) 
        self.teacher_textbox.grid(row=0, column=1, padx=5, pady=5) 
 
        self.label = tk.Label(root, text="Lớp giảng dạy:") 
        self.label.grid(row=1, column=0, padx=5, pady=5) 
 
        self.combobox = ttk.Combobox(root, values=self.options) 
        self.combobox.grid(row=1, column=1, padx=5, pady=5) 
 
        self.combobox.bind("<<ComboboxSelected>>", self.on_select) 
 
    def on_select(self, event): 
        selected_value = self.combobox.get() 
        print("Selected:", selected_value) 
 
root = tk.Tk() 
app = ComboboxApp(root) 
root.mainloop()
# Out:
# Selected: DHDS17A1
