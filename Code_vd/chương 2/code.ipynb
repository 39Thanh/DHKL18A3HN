# %%
import json
data = {"name":"nguyen van a","age":23, "skills":["AI","Python"]}

# %%
import json

def complex_handler(obj):
    if isinstance(obj, complex):
        return [obj.real, obj.imag]
    raise TypeError(repr(obj) + " khong the ma hoa json")
data = {"z": 2 + 3j}
complex_json = json.dumps(data, default=complex_handler)
print(complex_obj)

# %%
data = {"z": 2 + 3j}

# %%
data={1,2,3}
complex_json = json.dumps(data, default=complex_handler)
print(complex_obj)

# %%
import json 
# Đối tượng Python (đối tượng JSON) 
data = { 
"name": "A", 
"age": 35, 
"company": "Đất Việt" 
} 
# Chuyển đối tượng Python thành chuỗi JSON 
json_string = json.dumps(data, ensure_ascii=False) 
print(json_string) 
print(type(json_string))
# Out:
# {"name": "A", "age": 35, "company": "Đất Việt"}
# <class 'str'>

# %%
import json

data = {
    "ho_va_ten": "Nguyễn Văn A", 
    "nam_sinh": 2005,
    "gioi_tinh": "Nam", 
    "sdt": "0123456789", 
    "email": "nguyenvana@uneti.edu.vn"
}

with open('thongtin.json', 'w', encoding='utf-8') as f:
          json.dump(data, f, ensure_ascii=False, indent=4)
print("ghi file thanh cong")
# Out:
# ghi file thanh cong

# %%
import json
def is_complex(obj):
    if '__complex__' in object:
        return complex(obj['real'], obj['img'])
    return obj
def main():
    complex_obj = json.loads('{"__complex__": true, "real":4,"img":5}'),

# %%
import json 

json_string_1 = '{"name": "A", "age": 35, "company": "Đất Việt"}' 
json_string_2 = "{\"name\": \"A\", \"age\": 35, \"company\": \"Đất Việt\"}" 
json_object_1 = json.loads(json_string_1) 
json_object_2 = json.loads(json_string_2) 
 
print(json_object_1) 
print(json_object_2)
# Out:
# {'name': 'A', 'age': 35, 'company': 'Đất Việt'}
# {'name': 'A', 'age': 35, 'company': 'Đất Việt'}

# %%
import json 
  
with open('thongtin.json', 'r', encoding='utf-8') as f:
    infor = json.load(f) 
    print(infor) 
    print(type(infor))
# Out:
# {'ho_va_ten': 'Nguyễn Văn A', 'nam_sinh': 2005, 'gioi_tinh': 'Nam', 'sdt': '0123456789', 'email': 'nguyenvana@uneti.edu.vn'}
# <class 'dict'>

# %%
import json 
class CustomObject: 
    def __init__(self, data):
        self.data = data 
    def to_dict(seltf):
        return {"custom_data": self.data} 
class CustomObjectEncoder(json.JSONEncoder): 
    def default(self, obj): 
        if isinstance(obj, CustomObject): 
            return  obj.to_dict()  
        return super().default(obj)
data = {"item": CustomObject("CT", 42)}
data_st=(json.dumps(data, cls=CustomObjectEncoder, ensure_ascii=False, indent=2))
print(data_st)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 12
#      10             return  obj.to_dict()
#      11         return super().default(obj)
# ---> 12 data = {"item": CustomObject("CT", 42)}
#      13 data_st=(json.dumps(data, cls=CustomObjectEncoder, ensure_ascii=False, indent=2))
#      14 print(data_st)
#
# TypeError: CustomObject.__init__() takes 2 positional arguments but 3 were given

# %%
from json.encoder import JSONEncoder 

colour_dict = { "colour": ["red", "yellow", "green" ]}  
json_string=JSONEncoder().encode(colour_dict) 

print(json_string) 
print(type(json_string))
# Out:
# {"colour": ["red", "yellow", "green"]}
# <class 'str'>

# %%
import json 
from json.decoder import JSONDecoder 

colour_string = '{ "colour": ["red", "yellow"]}'  
decoded_object = JSONDecoder().decode(colour_string) 

print(decoded_object) 
print(type(decoded_object))
# Out:
# {'colour': ['red', 'yellow']}
# <class 'dict'>
